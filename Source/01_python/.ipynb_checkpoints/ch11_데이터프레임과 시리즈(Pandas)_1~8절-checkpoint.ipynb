# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:99% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:22pt;}
div.text_cell_render.rendered_html{font-size:18pt;}
div.output {font-size:22pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:22pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:22pt;padding:5px;}
table.dataframe{font-size:22px;}
</style>
"""))

# %% [markdown]
# <b><font size="7" color="red">ch10. N차원 배열(Numpy 배열) 다루기</font></b>
#
# # 1절 판타스 패키지
# - 데이터 분석을 위해 반드시 알아야 할 패키지
# - 넘파이를 기본을 하며 다른 많은 라이브러리와 잘 통합되도록 설계
# - 2차원 구조를 갖는 데이터프레임, 1차원 구조를 갖는 시리즈를 제공
# - 판다스 장점 :
#    * 데이터프레임생성, 생성io, 레이블링, 부분데이터 추출,
#    * 크기변경(행이나 열 삽입, 삭제), 데이터 분할, 병합, 데이터구조변경, 결측치 처리
# • https://pypi.python.org/pypi/pandas(package index)
# • http://pandas.pydata.org/pandas-docs/stable/api.html(API reference)

# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.3'

# %%
pd.read_json?

# %%
data = pd.read_json('data/ch09_member1.json', encoding='cp949')
data
print(type(data))
print(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#   name  age    email address
# 0  홍길동   20  h@h.com      서울
# 1  김길동   30  k@h.com      부산
# 2  신길동   40  s@h.com      안양

# %%
member4 = pd.read_csv('data/ch09_member4.csv')
member4
# Out:
#   name  age    email   address  job
# 0  홍길동   20  h@h.com   서울시 관악구  NaN
# 1  신길동   40  s@h.com  서울시 영등포구   팀장
# 2  김길동   30  k@h.com   서울시 동작구  NaN

# %%
member4 = pd.read_csv('data/ch09_member1.csv', header=None)
member4
# Out:
#      0   1                 2         3
# 0  홍길동  20  kildong@hong.com   서울시 관악구
# 1  김길동  40  kimdong@hong.com  서울시 영등포구
# 2  신길동  30  sindong@hong.com   서울시 동작구

# %%
member1 = pd.read_csv('data/ch09_member1.csv', header=None, names=['name','age','email','address'])
member1
# Out:
#   name  age             email   address
# 0  홍길동   20  kildong@hong.com   서울시 관악구
# 1  김길동   40  kimdong@hong.com  서울시 영등포구
# 2  신길동   30  sindong@hong.com   서울시 동작구

# %% [markdown]
# # 2절 데이터프레임 만들기
# ## 2.1 딕셔너리 리스트를 이용해서 데이터 프레임 만들기

# %%
import pandas as pd
pd.__version__
d = [{'kor':100, 'mat':95}, {'kor':90, 'mat':99}]
df = pd.DataFrame(data=d)
df
# Out:
#    kor  mat
# 0  100   95
# 1   90   99

# %%
df.to_dict()  # 데이터프레임을 딕셔너리로

# %%
{'kor':{0: 100, 1: 90}, 'mat':{0: 95, 1: 99}}
# Out:
# {'kor': {0: 100, 1: 90}, 'mat': {0: 95, 1: 99}}

# %%
df.to_numpy()  # 데이터프레임을 넘파이배열
df.values     # 데이터프레임을 넘파이배열
# Out:
# array([[100,  95],
#        [ 90,  99]], dtype=int64)

# %%
df.dtypes    # 열의 타입
# Out:
# kor    int64
# mat    int64
# dtype: object

# %%
df.info()   # ★
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   kor     2 non-null      int64
#  1   mat     2 non-null      int64
# dtypes: int64(2)
# memory usage: 160.0 bytes

# %%
df['kor'].dtype
# Out:
# dtype('int64')

# %%
# 타입변경(열마다)
import numpy as np
df['kor'].astype(np.float64)
df['kor'].astype('float64')   # kor 열의 타입을 float64로
# Out:
# 0    100.0
# 1     90.0
# Name: kor, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   kor     2 non-null      int64
#  1   mat     2 non-null      int64
# dtypes: int64(2)
# memory usage: 160.0 bytes

# %%
d = [{'kor':100, 'mat': 95}, {'kor':90, 'math':99}, {'kor':92 , 'eng':99}]
df = pd.DataFrame(data=d)
df
# Out:
#    kor   mat  math   eng
# 0  100  95.0   NaN   NaN
# 1   90   NaN  99.0   NaN
# 2   92   NaN   NaN  99.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   kor     3 non-null      int64
#  1   mat     1 non-null      float64
#  2   math    1 non-null      float64
#  3   eng     1 non-null      float64
# dtypes: float64(3), int64(1)
# memory usage: 224.0 bytes

# %%
type(np.nan)
# Out:
# float

# %%
df['kor'] = df['kor'].astype('int32')
df
# Out:
#    kor   mat  math   eng
# 0  100  95.0   NaN   NaN
# 1   90   NaN  99.0   NaN
# 2   92   NaN   NaN  99.0

# %%
# 결측치는 int로 형변환 불가(결측지를 대체값으로 치환 후 변환)
df['mat'] = df['meat'].astyp('int32')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda4\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda4\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda4\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'meat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ## 2.2 리스트를 이용해서 데이터 프레임 만들기
# kor = [100,90,95,90,65]
# mat = [99,100,95,98,94]
# df = pd.DataFrame(data=np.c_['kor':kor], clolums=['국어', '수학'])
# df

# %%
l = [['트렌드 코리가2026', '김난도', 18000, 10],
     ['사탄탱고2026', '라슬로', 100, 10],
     ['미술관 영행자', '카미유주노', 29700, 10]]
df
# Out:
#    kor   mat  math   eng
# 0  100  95.0   NaN   NaN
# 1   90   NaN  99.0   NaN
# 2   92   NaN   NaN  99.0

# %%
# %ls "C:\AI_X_Practice_0911\downloads\shareData\상가정보"
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: A014-DCD6
#
#  C:\AI_X_Practice_0911\downloads\shareData\상가정보 디렉터리
#
# 2025-10-12  오후 03:33    <DIR>          .
# 2025-10-12  오후 03:33    <DIR>          ..
# 2025-04-27  오후 11:07             1,011 [필독]파일열람방법.txt
# 2025-04-27  오후 11:07        61,227,944 소상공인시장진흥공단_상가(상권)정보_강원_202503.csv
# 2025-04-27  오후 11:07       356,572,082 소상공인시장진흥공단_상가(상권)정보_경기_202503.csv
# 2025-04-27  오후 11:07        93,472,559 소상공인시장진흥공단_상가(상권)정보_경남_202503.csv
# 2025-04-27  오후 11:07        76,425,275 소상공인시장진흥공단_상가(상권)정보_경북_202503.csv
# 2025-04-27  오후 11:07        40,070,868 소상공인시장진흥공단_상가(상권)정보_광주_202503.csv
# 2025-04-27  오후 11:07        61,715,005 소상공인시장진흥공단_상가(상권)정보_대구_202503.csv
# 2025-04-27  오후 11:07        41,491,092 소상공인시장진흥공단_상가(상권)정보_대전_202503.csv
# 2025-04-27  오후 11:07        84,550,600 소상공인시장진흥공단_상가(상권)정보_부산_202503.csv
# 2025-04-27  오후 11:07       294,549,483 소상공인시장진흥공단_상가(상권)정보_서울_202503.csv
# ...

# %%
df = pd.read_csv(r'C:\AI_X_Practice_0911\downloads\shareData\상가정보\소상공인시장진흥공단_상가(상권)정보_전남_202503.csv')
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_4216\1419390782.py:1: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\AI_X_Practice_0911\downloads\shareData\상가정보\소상공인시장진흥공단_상가(상권)정보_전남_202503.csv')

# %%
df.head(5)
# Out:
#                  상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 0  MA010120220700003753       장안홍어  NaN        G2       소매      G205   식료품 소매
# 1  MA010120220700005734  초이스쌤수학교습소  NaN        P1       교육      P105    일반 교육
# 2  MA010120220700009750     부여장묘관리  NaN        S2    수리·개인      S210    장례식장
# 3  MA010120220700013702       중앙농산  NaN        G2       소매      G205   식료품 소매
# 4  MA010120220700017998     한양내과의원  NaN        Q1     보건의료      Q102       의원
#
#   상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...                     건물관리번호     건물명  \
# 0    G20505    수산물 소매업   G47214  ...  4684025021100210006000001  무안전통시장
# 1    P10501    입시·교과학원   P85501  ...  4689025022110620002000001     NaN
# 2    S21001       장례식장   S96921  ...  4673037028104190001024291     NaN
# 3    G20506  채소/과일 소매업   G47215  ...  4673025021101890005019723     NaN
# 4    Q10201  내과/소아과 의원   Q86201  ...  4679025022100850002042559     NaN
#
# ...

# %%
# 판다스 디스플레이 옵션
import pandas as pd
pd.options.display.max_columns = 39
pd.options.display.max_rows = 70
df
# Out:
#                      상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0      MA010120220700003753       장안홍어  NaN        G2       소매      G205
# 1      MA010120220700005734  초이스쌤수학교습소  NaN        P1       교육      P105
# 2      MA010120220700009750     부여장묘관리  NaN        S2    수리·개인      S210
# 3      MA010120220700013702       중앙농산  NaN        G2       소매      G205
# 4      MA010120220700017998     한양내과의원  NaN        Q1     보건의료      Q102
# ...                     ...        ...  ...       ...      ...       ...
# 99403  MA0103202406C0037272         샤인  NaN        I2       음식      I211
# 99404  MA0103202411C0032474     딜리버리티나  NaN        I2       음식      I201
# 99405  MA0101202502A0099737     마동욱사진방  NaN        M1    과학·기술      M113
# 99406  MA0101202502A0102458       기념품점  NaN        G2       소매      G218
# 99407  MA0101202502A0111410      모내기래쉬  NaN        S2    수리·개인      S207
#
#       상권업종중분류명 상권업종소분류코드   상권업종소분류명 표준산업분류코드                 표준산업분류명  시도코드  \
# ...

# %%
df.head(2)
# Out:
#                  상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 0  MA010120220700003753       장안홍어  NaN        G2       소매      G205   식료품 소매
# 1  MA010120220700005734  초이스쌤수학교습소  NaN        P1       교육      P105    일반 교육
#
#   상권업종소분류코드 상권업종소분류명 표준산업분류코드              표준산업분류명  시도코드   시도명  시군구코드 시군구명  \
# 0    G20505  수산물 소매업   G47214  신선; 냉동 및 기타 수산물 소매업    46  전라남도  46840  무안군
# 1    P10501  입시·교과학원   P85501              일반 교과학원    46  전라남도  46890  완도군
#
#       행정동코드 행정동명       법정동코드 법정동명                 지번코드  대지구분코드 대지구분명   지번본번지  \
# 0  46840250  무안읍  4684025021  무안읍  4684025021100210006       1    대지    21.0
# 1  46890250  완도읍  4689025022  완도읍  4689025022110620002       1    대지  1062.0
#
#    지번부번지                     지번주소         도로명코드                    도로명  건물본번지  \
# 0    6.0    전라남도 무안군 무안읍 성내리 21-6  468403296023       전라남도 무안군 무안읍 승달로     11
# 1    2.0  전라남도 완도군 완도읍 가용리 1062-2  468904700010  전라남도 완도군 완도읍 개포로135번길     32
#
# ...

# %%
df.head(1).T
# Out:
#                                    0
# 상가업소번호          MA010120220700003753
# 상호명                             장안홍어
# 지점명                              NaN
# 상권업종대분류코드                         G2
# 상권업종대분류명                          소매
# 상권업종중분류코드                       G205
# 상권업종중분류명                      식료품 소매
# 상권업종소분류코드                     G20505
# 상권업종소분류명                     수산물 소매업
# 표준산업분류코드                      G47214
# 표준산업분류명          신선; 냉동 및 기타 수산물 소매업
# 시도코드                              46
# 시도명                             전라남도
# 시군구코드                          46840
# 시군구명                             무안군
# 행정동코드                       46840250
# 행정동명                             무안읍
# 법정동코드                     4684025021
# 법정동명                             무안읍
# 지번코드             4684025021100210006
# 대지구분코드                             1
# 대지구분명                             대지
# 지번본번지                           21.0
# 지번부번지                            6.0
# ...

# %% [markdown]
# ## 2.3 read_csv

# %%
# help(pd.read_csv)
# pd.read_csv()  # 함수 안에서 shift+tab+tab
pd.read_csv?

# %%
# (1) CSV 파일 불러오기(기본값)
member = pd.read_csv('data/ch11_member.csv')
member
# Out:
#    Name  Age          Email  Address       Birth
# 0   홍길동   20  hong@hong.com  서울시 강동구  1999-01-01
# 1   홍길서   30   seo@hong.com   서울시 중구  1999-12-01
# 2   홍길남   21   nam@hong.com  서울시 강동구  1999-11-01
# 3   홍길북   22   buk@hong.com  서울시 관악구  1999-05-01
# 4   홍길중   23   mid@hong.com   부산시 중구  1999-01-30
# 5  #홍길뜽   24    non@not.com      없는구  2000-01-01

# %%
# (1) CSV 파일 불러오기(기본값)
member = pd.read_csv('data/ch11_member.csv')
member.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     6 non-null      object
#  1   Age      6 non-null      int64
#  2   Email    6 non-null      object
#  3   Address  6 non-null      object
#  4   Birth    6 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 368.0+ bytes

# %%
# 문자형으로 읽어들인 Birth를 datatime형으로 
# 형변환 : astype('int64'), astype('datetime64')
#          to_datetime()함수
member['Birth'].astype('datetime64')
member['Birth'] = pd.to_datetime(member['Birth'])
member
# Out:
#    Name  Age          Email  Address      Birth
# 0   홍길동   20  hong@hong.com  서울시 강동구 1999-01-01
# 1   홍길서   30   seo@hong.com   서울시 중구 1999-12-01
# 2   홍길남   21   nam@hong.com  서울시 강동구 1999-11-01
# 3   홍길북   22   buk@hong.com  서울시 관악구 1999-05-01
# 4   홍길중   23   mid@hong.com   부산시 중구 1999-01-30
# 5  #홍길뜽   24    non@not.com      없는구 2000-01-01

# %%
import numpy as np
member['Age'] = member['Age'].astype(np.int16)
member.dtypes
# Out:
# Name               object
# Age                 int16
# Email              object
# Address            object
# Birth      datetime64[ns]
# dtype: object

# %%
# (2) 특정행을 제외하고 csv 파일 읽어오기
member = pd.read_csv('data\ch11_membercp949.csv', nrows=5)
member
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[66], line 2
#       1 # (2) 특정행을 제외하고 csv 파일 읽어오기
# ----> 2 member = pd.read_csv('data\ch11_membercp949.csv', nrows=5)
#       3 member
#
# File ~\anaconda4\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda4\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
# (3) 상위 몇행만 sep문자는, 아닌 csv파일 읽어오기
member = pd.read_csv('data/ch11_membersep.csv', nrows=5, sep='|')
member
# Out:
#   Name  Age          Email  Address       Birth
# 0  홍길동   20  hong@hong.com  서울시 강동구  1999-01-01
# 1  홍길서   30   seo@hong.com   서울시 중구  1999-12-01
# 2  홍길남   21   nam@hong.com  서울시 강동구  1999-11-01
# 3  홍길북   22   buk@hong.com  서울시 관악구  1999-05-01
# 4  홍길중   23   mid@hong.com   부산시 중구  1999-01-30

# %%
# (4) 주석(#)제외, datetime형 필드를 지정하여 csv 파일 읽어오기
member = pd.read_csv('data/ch11_membertab.csv',sep='\t', comment='#')
member.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     5 non-null      object
#  1   Age      5 non-null      int64
#  2   Email    5 non-null      object
#  3   Address  5 non-null      object
#  4   Birth    5 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 328.0+ bytes

# %%
member = pd.read_csv('data/ch11_membertab.csv',
                     sep='\t', 
                     comment='#',
                     partse_dates=['Birth'])
member.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 member = pd.read_csv('data/ch11_membertab.csv',
#       2                      sep='\t',
#       3                      comment='#',
#       4                      partse_dates=['Birth'])
#       5 member.info()
#
# File ~\anaconda4\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda4\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %% [markdown]
# ## 2.4 패키지에서 가져오기 : iris 데이터
# - iris 가져오기 방법1 : sklearn(머신러닝 패키지)
# - iris 가져오기 방법2 : satesmodels (R 데이터)
# - iris 가져오기 방법3 : seaborn (시각화패키지)
#
# ### 2.4.1 iris 방법1 : sklearn
# - sklearn.datasets 모듈 데이터(iris)를 데이터 프레임으로 변환

# %%
from sklearn import datasets # 머신 러닝을 공부하기 위한 학습 데이터셋 제공
